# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
data = pd.DataFrame ({
    'Hours': [1, 2, 3, 4.5, 5, 6, 7, 8.5, 9, 10],
    'Marks': [35, 40, 50, 60, 62, 70, 75, 85, 88, 95]
})
data.head()
# Out:
#    Hours  Marks
# 0    1.0     35
# 1    2.0     40
# 2    3.0     50
# 3    4.5     60
# 4    5.0     62

# %%
X = data[["Hours"]]
y = data["Marks"]

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
y_pred
# Out:
# array([35.37902265, 42.03575685, 48.69249106, 58.67759237, 62.00595948,
#        68.66269368, 75.31942789, 85.3045292 , 88.63289631, 95.28963051])

# %%
Intercept = model.intercept_
Slope = model.coef_[0]
mse = mean_squared_error(y,y_pred)
r2 = r2_score(y,y_pred)

# %%
print("Intercept:",Intercept)
print("Slope",Slope)
print("MSE:",mse)
print("R2:",r2)
# Out:
# Intercept: 28.722288438617404
# Slope 6.65673420738975
# MSE: 1.0213945172824785
# R2: 0.9972602078399075

# %%
plt.scatter(X,y,color="Blue",label="Actual Marks")
plt.plot(X,y_pred,color="Red",label="Regression Line")
plt.title("Study Hours vs Marks")
plt.xlabel("Hours of study")
plt.ylabel("Marks")
plt.legend()
plt.grid(True)
plt.show()

# %%
test_hrs = [[6.5]]
predicted_value = model.predict(test_hrs)
print(f"Predicted Marks:{predicted_value[0]:.2f}")
# Out:
# Predicted Marks:71.99
# C:\Users\SANANDITA HAZRA\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
