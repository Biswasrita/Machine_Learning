# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits

# %%
digits = load_digits()
X = digits.data
y = digits.target
print("Original shape:", X.shape)
# Out:
# Original shape: (1797, 64)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
print("Reduced shape:", X_pca.shape)
print("Explained variance ratio:", pca.explained_variance_ratio_)
# Out:
# Reduced shape: (1797, 2)
# Explained variance ratio: [0.14890594 0.13618771]

# %%
scatter= plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap="tab10")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA on Digits Dataset (64D → 2D)")
plt.colorbar(scatter, label="Digit Label")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\SANANDITA HAZRA\AppData\Local\Temp\ipykernel_17912\337786598.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
pca_full = PCA().fit(X)

# %%
plt.plot(np.cumsum(pca_full.explained_variance_ratio_))
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Explained Variance vs Components")
plt.grid(True)
plt.show()
